# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %% [markdown]
# # Oscars Dataframe Work

# %%
oscars_df = pd.read_csv("../Data/BigML_Dataset_5f50a62c2fb31c516d000176.csv")
oscars_df
# Out:
#       year                                              movie   movie_id  \
# 0     2001                                     Kate & Leopold  tt0035423
# 1     2000                                        Chicken Run  tt0120630
# 2     2005                                     Fantastic Four  tt0120667
# 3     2002                                              Frida  tt0120679
# 4     2001  The Lord of the Rings: The Fellowship of the Ring  tt0120737
# ...    ...                                                ...        ...
# 1178  2017                               Call Me by Your Name  tt5726616
# 1179  2017                                     Phantom Thread  tt5776858
# 1180  2017                                   Victoria & Abdul  tt5816682
# 1181  2017                              Roman J. Israel, Esq.  tt6000478
# 1182  2017                                           The Post  tt6294822
#
#      certificate  duration                       genre  rate  metascore  \
# ...

# %%
for col in oscars_df.columns: 
    print(col)
# Out:
# year
# movie
# movie_id
# certificate
# duration
# genre
# rate
# metascore
# synopsis
# votes
# gross
# release_date
# user_reviews
# critic_reviews
# popularity
# awards_wins
# awards_nominations
# Oscar_Best_Picture_won
# Oscar_Best_Picture_nominated
# Oscar_Best_Director_won
# Oscar_Best_Director_nominated
# Oscar_Best_Actor_won
# Oscar_Best_Actor_nominated
# Oscar_Best_Actress_won
# Oscar_Best_Actress_nominated
# Oscar_Best_Supporting_Actor_won
# Oscar_Best_Supporting_Actor_nominated
# Oscar_Best_Supporting_Actress_won
# Oscar_Best_Supporting_Actress_nominated
# Oscar_Best_AdaScreen_won
# Oscar_Best_AdaScreen_nominated
# Oscar_Best_OriScreen_won
# Oscar_Best_OriScreen_nominated
# Oscar_nominated
# Oscar_nominated_categories
# Golden_Globes_won
# Golden_Globes_won_categories
# Golden_Globes_nominated
# Golden_Globes_nominated_categories
# BAFTA_won
# BAFTA_won_categories
# BAFTA_nominated
# BAFTA_nominated_categories
# Screen_Actors_Guild_won
# Screen_Actors_Guild_won_categories
# ...

# %%
copied_oscars_df = oscars_df.drop(oscars_df.filter(regex='nominated').columns, axis=1)
copied_oscars_df
# Out:
#       year                                              movie   movie_id  \
# 0     2001                                     Kate & Leopold  tt0035423
# 1     2000                                        Chicken Run  tt0120630
# 2     2005                                     Fantastic Four  tt0120667
# 3     2002                                              Frida  tt0120679
# 4     2001  The Lord of the Rings: The Fellowship of the Ring  tt0120737
# ...    ...                                                ...        ...
# 1178  2017                               Call Me by Your Name  tt5726616
# 1179  2017                                     Phantom Thread  tt5776858
# 1180  2017                                   Victoria & Abdul  tt5816682
# 1181  2017                              Roman J. Israel, Esq.  tt6000478
# 1182  2017                                           The Post  tt6294822
#
#      certificate  duration                       genre  rate  metascore  \
# ...

# %%
dropped_oscars=copied_oscars_df.drop(['movie_id', 'release_date.day-of-month', 'release_date.day-of-week', 'release_date.year'], axis=1)
dropped_oscars
# Out:
#       year                                              movie certificate  \
# 0     2001                                     Kate & Leopold       PG-13
# 1     2000                                        Chicken Run           G
# 2     2005                                     Fantastic Four       PG-13
# 3     2002                                              Frida           R
# 4     2001  The Lord of the Rings: The Fellowship of the Ring       PG-13
# ...    ...                                                ...         ...
# 1178  2017                               Call Me by Your Name           R
# 1179  2017                                     Phantom Thread           R
# 1180  2017                                   Victoria & Abdul       PG-13
# 1181  2017                              Roman J. Israel, Esq.       PG-13
# 1182  2017                                           The Post       PG-13
#
#       duration                       genre  rate  metascore  \
# ...

# %%
dropped_oscars["gross"].dtype
# Out:
# dtype('float64')

# %%
no_nans_oscars=dropped_oscars.replace(np.nan, 0)

# %%
cols = ['gross', 'release_date.month', 'metascore', 'user_reviews', 'critic_reviews']
no_nans_oscars[cols] = no_nans_oscars[cols].applymap(np.int64)
no_nans_oscars.sample(5)
# Out:
#      year                                              movie certificate  \
# 339  2005  The Chronicles of Narnia: The Lion, the Witch ...          PG
# 780  2011               Mission: Impossible - Ghost Protocol       PG-13
# 376  2006                                      Casino Royale       PG-13
# 18   2000                                    American Psycho           R
# 969  2012                                       End of Watch           R
#
#      duration                      genre  rate  metascore  \
# 339       143   Adventure|Family|Fantasy   6.9         75
# 780       133  Action|Adventure|Thriller   7.4         73
# 376       144  Action|Adventure|Thriller   8.0         80
# 18        102                Crime|Drama   7.6         64
# 969       109       Crime|Drama|Thriller   7.7         68
#
#                                               synopsis   votes      gross  \
# 339  Four kids travel through a wardrobe to the lan...  297403  291710000
# ...

# %%
how_many_genres = []
cartoon= []

for index, row in no_nans_oscars.iterrows():
    if 'Animation' in row['genre']:
        cartoon.append(True)
    else:
        cartoon.append(False)
        
    number_of_genres = len(row['genre'].split("|"))
    how_many_genres.append(number_of_genres)

no_nans_oscars['cartoon'] = cartoon
no_nans_oscars['number_of_genres'] = how_many_genres
no_nans_oscars.sample(5)
# Out:
#      year                                    movie certificate  duration  \
# 970  2012               Resident Evil: Retribution           R        96
# 692  2008  The Sisterhood of the Traveling Pants 2       PG-13       119
# 968  2013           Percy Jackson: Sea of Monsters          PG       106
# 575  2009                                   Avatar       PG-13       162
# 514  2006                            Grandma's Boy           R        94
#
#                         genre  rate  metascore  \
# 970      Action|Horror|Sci-Fi   5.4         39
# 692       Comedy|Drama|Family   6.2         63
# 968  Adventure|Family|Fantasy   5.9         39
# 575  Action|Adventure|Fantasy   7.9         83
# 514                    Comedy   7.0         33
#
#                                               synopsis   votes      gross  \
# 970  Alice fights alongside a resistance movement t...  108238   42350000
# 692  Carmen Lowell is working on the backstage of a...   22953   44090000
# ...

# %%
renamed_oscars= no_nans_oscars.rename(columns={'movie':'movie_title'})

# %%
oscars_df_final=renamed_oscars[["year", "movie_title", "certificate", "duration", "genre", "rate", "metascore", "votes", "gross", "user_reviews", "critic_reviews", "cartoon", "number_of_genres"]].copy(
    ).reset_index(drop=True)
oscars_df_final.head()
# Out:
#    year                                        movie_title certificate  \
# 0  2001                                     Kate & Leopold       PG-13
# 1  2000                                        Chicken Run           G
# 2  2005                                     Fantastic Four       PG-13
# 3  2002                                              Frida           R
# 4  2001  The Lord of the Rings: The Fellowship of the Ring       PG-13
#
#    duration                       genre  rate  metascore    votes      gross  \
# 0       118      Comedy|Fantasy|Romance   6.4         44    66660   47100000
# 1        84  Animation|Adventure|Comedy   7.0         88   144475  106790000
# 2       106     Action|Adventure|Family   5.7         40   273203  154700000
# 3       123     Biography|Drama|Romance   7.4         61    63852   25780000
# 4       178     Adventure|Drama|Fantasy   8.8         92  1286275  313840000
#
#    user_reviews  critic_reviews  cartoon  number_of_genres
# ...

# %%
oscars_clean_df=oscars_df_final.drop_duplicates(['movie_title'] , keep ='last') 
oscars_clean_df.shape
# Out:
# (1182, 13)

# %%
oscars_clean_df.to_csv("../Output/oscars_clean_df.csv", index=False)

# %%
nominations_df=renamed_oscars[["year", "movie_title", "awards_wins", "awards_nominations", "Oscar_Best_Picture_won","Oscar_Best_Director_won","Oscar_Best_Actor_won","Oscar_Best_Actress_won","Oscar_Best_Supporting_Actor_won","Oscar_Best_Supporting_Actress_won","Oscar_Best_AdaScreen_won","Oscar_Best_OriScreen_won"]].copy(
    ).reset_index(drop=True)
nominations_df.head()
# Out:
#    year                                        movie_title  awards_wins  \
# 0  2001                                     Kate & Leopold            1
# 1  2000                                        Chicken Run            5
# 2  2005                                     Fantastic Four            0
# 3  2002                                              Frida            2
# 4  2001  The Lord of the Rings: The Fellowship of the Ring           26
#
#    awards_nominations Oscar_Best_Picture_won Oscar_Best_Director_won  \
# 0                   4                     No                      No
# 1                  11                     No                      No
# 2                   0                     No                      No
# 3                  12                     No                      No
# 4                  67                     No                      No
#
#   Oscar_Best_Actor_won Oscar_Best_Actress_won Oscar_Best_Supporting_Actor_won  \
# ...

# %%
nominations_df.columns = nominations_df.columns.str.lower()

# %%
unique_oscars=nominations_df.drop_duplicates(['movie_title'] , keep ='last')

# %%
oscar_wins_df=unique_oscars.replace(["Yes", "No"], [True, False])
oscar_wins_df.head()
# Out:
#    year                                        movie_title  awards_wins  \
# 0  2001                                     Kate & Leopold            1
# 1  2000                                        Chicken Run            5
# 2  2005                                     Fantastic Four            0
# 3  2002                                              Frida            2
# 4  2001  The Lord of the Rings: The Fellowship of the Ring           26
#
#    awards_nominations  oscar_best_picture_won  oscar_best_director_won  \
# 0                   4                   False                    False
# 1                  11                   False                    False
# 2                   0                   False                    False
# 3                  12                   False                    False
# 4                  67                   False                    False
#
#    oscar_best_actor_won  oscar_best_actress_won  \
# 0                 False                   False
# ...

# %%
oscar_wins_df.to_csv("../Output/oscar_wins_df.csv", index=False)

# %% [markdown]
# # Wiki Dataframe Work

# %%
wiki_df = pd.read_csv("../Data/wiki_movie_plots_deduped.csv")
wiki_df
# Out:
#       Release Year                             Title Origin/Ethnicity  \
# 0             1901            Kansas Saloon Smashers         American
# 1             1901     Love by the Light of the Moon         American
# 2             1901           The Martyred Presidents         American
# 3             1901  Terrible Teddy, the Grizzly King         American
# 4             1902            Jack and the Beanstalk         American
# ...            ...                               ...              ...
# 34887         2014                 The Water Diviner          Turkish
# 34888         2017                Çalgı Çengi İkimiz          Turkish
# 34889         2017                      Olanlar Oldu          Turkish
# 34890         2017                  Non-Transferable          Turkish
# 34891         2017                İstanbul Kırmızısı          Turkish
#
#                                  Director  \
# 0                                 Unknown
# ...

# %%
filtered_wiki_df = wiki_df.loc[(wiki_df["Origin/Ethnicity"]=="American")]
filtered_wiki_df
# Out:
#       Release Year                             Title Origin/Ethnicity  \
# 0             1901            Kansas Saloon Smashers         American
# 1             1901     Love by the Light of the Moon         American
# 2             1901           The Martyred Presidents         American
# 3             1901  Terrible Teddy, the Grizzly King         American
# 4             1902            Jack and the Beanstalk         American
# ...            ...                               ...              ...
# 17372         2017                     Crooked House         American
# 17373         2017                          Hostiles         American
# 17374         2017        All the Money in the World         American
# 17375         2017                      Molly's Game         American
# 17376         2017                    Phantom Thread         American
#
#                                  Director  \
# 0                                 Unknown
# ...

# %%
filtered_wiki_df.columns = filtered_wiki_df.columns.str.replace(' ', '_').str.lower()
renamed_df=filtered_wiki_df.rename(columns={'title':'movie_title', 'origin/ethnicity':'country', 'release_year':'year'}
                                  ).replace({'country': 'American'}, {'country': 'USA'})
renamed_df
# Out:
#        year                       movie_title country  \
# 0      1901            Kansas Saloon Smashers     USA
# 1      1901     Love by the Light of the Moon     USA
# 2      1901           The Martyred Presidents     USA
# 3      1901  Terrible Teddy, the Grizzly King     USA
# 4      1902            Jack and the Beanstalk     USA
# ...     ...                               ...     ...
# 17372  2017                     Crooked House     USA
# 17373  2017                          Hostiles     USA
# 17374  2017        All the Money in the World     USA
# 17375  2017                      Molly's Game     USA
# 17376  2017                    Phantom Thread     USA
#
#                                  director  \
# 0                                 Unknown
# 1                                 Unknown
# 2                                 Unknown
# 3                                 Unknown
# 4      George S. Fleming, Edwin S. Porter
# ...                                   ...
# ...

# %%
renamed_wiki_df = renamed_df.loc[(renamed_df["genre"]!="unknown")]

# %%
duplicates = renamed_wiki_df[renamed_wiki_df.duplicated(['movie_title'])] 
duplicates
# Out:
#        year                movie_title country  \
# 55     1913    Dr. Jekyll and Mr. Hyde     USA
# 85     1914               Laughing Gas     USA
# 240    1918              The Squaw Man     USA
# 286    1919     Nine-Tenths of the Law     USA
# 318    1920    Dr. Jekyll and Mr. Hyde     USA
# ...     ...                        ...     ...
# 17315  2017                 Flatliners     USA
# 17318  2017  My Little Pony: The Movie     USA
# 17328  2017             Only the Brave     USA
# 17336  2017                     Jigsaw     USA
# 17350  2017                   The Star     USA
#
#                               director  \
# 55     Herbert Brenon and Carl Laemmle
# 85                     Charlie Chaplin
# 240                   Cecil B. DeMille
# 286                    B. Reeves Eason
# 318                  John S. Robertson
# ...                                ...
# 17315                Niels Arden Oplev
# 17318                  Jayson Thiessen
# ...

# %%
unique_wiki_df=renamed_wiki_df.drop_duplicates(['movie_title'] , keep ='last') 
unique_wiki_df.shape
# Out:
# (16178, 9)

# %%
wiki_df_final=unique_wiki_df[["year", "movie_title", "country", "genre", "wiki_page"]].copy(
    ).reset_index(drop=True).dropna(how='all')
wiki_df_final.sample(5)
# Out:
#        year          movie_title country             genre  \
# 1924   1937              Parnell     USA  drama, biography
# 1323   1933  Three-Cornered Moon     USA            comedy
# 7832   1970   Dirty Dingus Magee     USA           western
# 12338  1999         Happy, Texas     USA            comedy
# 4465   1949   Neptune's Daughter     USA           musical
#
#                                                wiki_page
# 1924        https://en.wikipedia.org/wiki/Parnell_(film)
# 1323   https://en.wikipedia.org/wiki/Three-Cornered_Moon
# 7832    https://en.wikipedia.org/wiki/Dirty_Dingus_Magee
# 12338  https://en.wikipedia.org/wiki/Happy,_Texas_(film)
# 4465   https://en.wikipedia.org/wiki/Neptune%27s_Daug...

# %%
wiki_df_final['year'] = wiki_df_final['year'].apply(pd.to_numeric)

# %%
wiki_df_final = wiki_df_final[(wiki_df_final.year > 1999)]

# %%
wiki_df_final
# Out:
#        year                             movie_title country  \
# 12450  2000                          102 Dalmatians     USA
# 12451  2000                                 28 Days     USA
# 12452  2000                               3 Strikes     USA
# 12453  2000                             The 6th Day     USA
# 12454  2000  The Adventures of Rocky and Bullwinkle     USA
# ...     ...                                     ...     ...
# 16173  2017                           Crooked House     USA
# 16174  2017                                Hostiles     USA
# 16175  2017              All the Money in the World     USA
# 16176  2017                            Molly's Game     USA
# 16177  2017                          Phantom Thread     USA
#
#                          genre  \
# 12450           comedy, family
# 12451                    drama
# 12452                   comedy
# 12453          science fiction
# 12454                   comedy
# ...                        ...
# ...

# %%
wiki_df_final.to_csv("../Output/wiki_clean.csv", index=False)

# %% [markdown]
# # Connect Local Database

# %%
rds_connection_string = "postgres:3411@localhost:5432/ETL_project_movies_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['wiki_table', 'oscar_movies', 'oscar_wins']

# %% [markdown]
# # Load Dataframes into the Database

# %%
wiki_df_final.to_sql(name='wiki_table', con=engine, if_exists='append', index=False)

# %%
oscars_clean_df.to_sql(name='oscar_movies', con=engine, if_exists='append', index=False)

# %%
oscar_wins_df.to_sql(name='oscar_wins', con=engine, if_exists='append', index=False)

# %% [markdown]
# # Additional CSVs download

# %%
imdb_clean = pd.read_csv("../Output/IMBD_clean.csv")
imdb_clean.sample(5)
# Out:
#               movie_title  year                   genre  duration  \
# 10103            Returned  2015                  Sci-Fi        90
# 8275          Blood Widow  2014                  Horror        84
# 1967        Sons of Provo  2004           Comedy, Music        93
# 6144             10 Years  2011  Comedy, Drama, Romance       110
# 9023   The Night Is Young  2017         Comedy, Romance        91
#
#                     director  \
# 10103            Lamont Gant
# 8275       Jeremiah Buckhalt
# 1967            Will Swenson
# 6144            Jamie Linden
# 9023   Dave Hill, Matt Jones
#
#                                              description  avg_vote  \
# 10103  Benjamin Lathan's flight disappeared, twelve y...       2.7
# 8275   Laurie and Hugh are a successful young couple ...       2.9
# 1967   Will, Kirby, and Danny are the hottest new sen...       5.9
# 6144   The night of their high school reunion, a grou...       6.1
# ...

# %%
netflix_clean = pd.read_csv("../Output/Netflix_clean.csv")
netflix_clean.sample(5)
# Out:
#                   movie_title  \
# 550                Chal Bhaag
# 265            Audrie & Daisy
# 3135  What Happened to Monday
# 1067             HALO Legends
# 1421              Katti Batti
#
#                                                director  \
# 550                               Prakash Balwant Saini
# 265                              Bonni Cohen, Jon Shenk
# 3135                                      Tommy Wirkola
# 1067  Shinji Aramaki, Mamoru Oshii, Hideki Futamura,...
# 1421                                      Nikhil Advani
#
#                                                  actors  release_year rating  \
# 550   Deepak Dobriyal, Tarun Bajaj, Keeya Khanna, Va...          2014  TV-14
# 265                                                 NaN          2016  TV-MA
# 3135  Noomi Rapace, Willem Dafoe, Glenn Close, Marwa...          2017  TV-MA
# 1067  Andy McAvin, James Faulkner, Luci Christian, J...          2009  PG-13
# ...

# %% [markdown]
# # Load additional Dataframes to Database

# %%
imdb_clean.to_sql(name='imdb_data', con=engine, if_exists='append', index=False)

# %%
netflix_clean.to_sql(name='netflix_data', con=engine, if_exists='append', index=False)
