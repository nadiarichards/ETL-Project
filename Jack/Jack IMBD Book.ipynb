# %%
##Imports

import pandas as pd
from sqlalchemy import create_engine

# %%
##Store CSV into DataFrame

csv_file = "../Data/IMDb movies.csv"
IMBD_df = pd.read_csv(csv_file)
IMBD_df.sample(5)
# Out:
#       imdb_title_id                   title          original_title  year  \
# 35621     tt0193102       Dil Ka Kya Kasoor       Dil Ka Kya Kasoor  1992
# 36350     tt0206550           Anazitisis...           Anazitisis...  1972
# 32923     tt0144304      O Menino e o Vento      O Menino e o Vento  1967
# 62123     tt1805492                 Robo Jî                 Robo Jî  2012
# 3369      tt0031762  Avventurieri dell'aria  Only Angels Have Wings  1939
#
#       date_published                      genre  duration country  \
# 35621      1/14/1992           Musical, Romance       157   India
# 36350           1972               Crime, Drama        89  Greece
# 32923           1967                      Drama       104  Brazil
# 62123      1/14/2012              Comedy, Drama       111   Japan
# 3369        2/2/1942  Adventure, Drama, Romance       121     USA
#
#                language                 director  ...  \
# 35621             Hindi         Lawrence D'Souza  ...
# 36350             Greek          Erricos Andreou  ...
# 32923        Portuguese  Carlos Hugo Christensen  ...
# 62123          Japanese          Shinobu Yaguchi  ...
# 3369   English, Spanish             Howard Hawks  ...
#
#                                                   actors  \
# 35621  Prithvi, Divya Bharti, Sanam, Laxmikant Berde,...
# 36350  Angelos Antonopoulos, Elena Nathanail, Vasos A...
# 32923  Ênio Gonçalves, Luiz Fernando Ianelli, Wilma H...
# 62123  Naoto Takenaka, Yuriko Yoshitaka, Yoshiyuki Mo...
# 3369   Cary Grant, Jean Arthur, Richard Barthelmess, ...
#
#                                              description avg_vote  votes  \
# 35621  Shalini Saxena lives a wealthy life-style with...      5.8    172
# 36350  A rich and beautiful woman is seeking an adven...      6.0    101
# 32923  Young engineer on holiday gets involved with a...      7.2    117
# 62123  When some techs with no knowledge of robotics ...      6.9    615
# 3369   At a remote South American trading port, the m...      7.7  12164
#
#        budget  usa_gross_income worlwide_gross_income metascore  \
# 35621     NaN               NaN                   NaN       NaN
# 36350     NaN               NaN                   NaN       NaN
# 32923     NaN               NaN                   NaN       NaN
# 62123     NaN               NaN          $14,598,382        NaN
# 3369      NaN               NaN               $8,554       86.0
#
#       reviews_from_users  reviews_from_critics
# 35621                5.0                   NaN
# 36350                4.0                   NaN
# 32923                1.0                   NaN
# 62123                6.0                  15.0
# 3369                77.0                  95.0
#
# [5 rows x 22 columns]

# %%
##Read Columns

for col in IMBD_df.columns: 
    print(col)
# Out:
# imdb_title_id
# title
# original_title
# year
# date_published
# genre
# duration
# country
# language
# director
# writer
# production_company
# actors
# description
# avg_vote
# votes
# budget
# usa_gross_income
# worlwide_gross_income
# metascore
# reviews_from_users
# reviews_from_critics

# %%
##Cast year in to integer so to sort and drop
IMBD_df[['year']] = IMBD_df[['year']].apply(pd.to_numeric) 
print(IMBD_df.dtypes)
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                       int64
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
##Cast year in to integer so to sort and drop

IMBD_df = IMBD_df[(IMBD_df.country == "USA") & (IMBD_df.year > 1999) & (IMBD_df.year < 2018)] 
IMBD_df.sample(5)
# Out:
#       imdb_title_id                     title            original_title  year  \
# 37748     tt0240402   The Center of the World   The Center of the World  2001
# 32202     tt0132885                 BlackMale                 BlackMale  2000
# 67321     tt2442466  All the Light in the Sky  All the Light in the Sky  2012
# 70850     tt3340000                   Wichita                   Wichita  2014
# 63575     tt1977822                    Inside                    Inside  2012
#
#       date_published                     genre  duration country language  \
# 37748      5/18/2001            Drama, Romance        88     USA  English
# 32202      6/23/2000                  Thriller        90     USA  English
# 67321      12/3/2013                     Drama        79     USA  English
# 70850      5/16/2015  Drama, Thriller, Western       106     USA  English
# 63575     10/14/2014                    Horror        85     USA  English
#
#                          director  ...  \
# 37748                  Wayne Wang  ...
# 32202  George Baluzy, Mike Baluzy  ...
# 67321                Joe Swanberg  ...
# 70850             Nicholas Barton  ...
# 63575                 Daryn Tufts  ...
#
#                                                   actors  \
# 37748  Shane Edelman, Peter Sarsgaard, Molly Parker, ...
# 32202  Bokeem Woodbine, Roger Rees, Justin Pierce, Sa...
# 67321  Jane Adams, Sophia Takal, Kent Osborne, Larry ...
# 70850  Justin France, Karina Wolfe, Blake Webb, Reyly...
# 63575  Luke Goss, Paul Rae, Isaac C. Singleton Jr., D...
#
#                                              description avg_vote votes  \
# 37748  A successful computer engineer meets a strippe...      5.8  4529
# 32202  Two desperate con men attempt to blackmail a p...      4.6   351
# 67321  Jane Adams is an actress living in a house pre...      6.4   536
# 70850  A drifter, a fugitive, and a bounty hunter all...      8.1   114
# 63575  Locked in a prison cell Milles Berret must fac...      3.9   408
#
#           budget  usa_gross_income worlwide_gross_income metascore  \
# 37748        NaN       $1,101,344            $1,460,687       44.0
# 32202        NaN               NaN                   NaN       NaN
# 67321        NaN               NaN                   NaN      62.0
# 70850  $100,000                NaN                   NaN       NaN
# 63575        NaN               NaN                   NaN       NaN
#
#       reviews_from_users  reviews_from_critics
# 37748               72.0                  67.0
# 32202               17.0                   3.0
# 67321                7.0                  18.0
# 70850               38.0                   NaN
# 63575                6.0                   3.0
#
# [5 rows x 22 columns]

# %%
## Choose Columns,  drop rows where reviews_from_critics is NaN, remove duplicate movies
IMBD_df = IMBD_df.rename(columns={'title': 'movie_title'})
IMBD_df = IMBD_df[['movie_title', 'year', 'genre', 'duration', 'director', 'description', 'avg_vote', 'reviews_from_users', 'reviews_from_critics']].copy()

IMBD_df=IMBD_df.drop_duplicates(['movie_title'] , keep ='first') 

IMBD_df = IMBD_df.reset_index(drop=True)
IMBD_df.to_csv("../Output/IMBD_clean.csv")

IMBD_df.sample(10)
# Out:
#                      movie_title  year                   genre  duration  \
# 10688   Straight Outta Oakland 2  2017                   Drama        75
# 389              American School  2000         Comedy, Romance        98
# 3544                     Neowolf  2010        Horror, Thriller        88
# 5438     Innamorarsi a Middleton  2013         Comedy, Romance        99
# 1455             The Evil Within  2017                  Horror        98
# 4313   Il buongiorno del mattino  2010  Comedy, Drama, Romance       107
# 3327                      Asylum  2008        Horror, Thriller        93
# 9250                     Results  2015         Comedy, Romance       105
# 6641             Hold Your Peace  2011         Comedy, Romance        99
# 739                Extreme Force  2001                  Action        90
#
#                 director                                        description  \
# 10688  Marcus D. Spencer  Banneker is a desperate man. His two jobs aren...
# 389       Amy Heckerling  A college student, branded a loser by his room...
# 3544       Yvan Gauthier  Two college lovers face an ancient evil when a...
# 5438        Adam Rodgers  Two parents fall in love over the course of a ...
# 1455        Andrew Getty  The sadistic tale of a lonely, mentally handic...
# 4313       Roger Michell  An upstart television producer accepts the cha...
# 3327      David R. Ellis  Six college students discover their dorm was o...
# 9250     Andrew Bujalski  Two mismatched personal trainers' lives are up...
# 6641       Wade McDonald  Hold Your Peace is the story of Aiden, a man a...
# 739         Michel Qissi  An international thief becomes a hero as he se...
#
#        avg_vote  reviews_from_users  reviews_from_critics
# 10688       8.0                 1.0                   NaN
# 389         5.3               168.0                  87.0
# 3544        2.1                 5.0                  13.0
# 5438        6.5                45.0                  65.0
# 1455        5.5                46.0                  34.0
# 4313        6.5               186.0                 219.0
# 3327        4.1                43.0                  41.0
# 9250        5.4                31.0                  92.0
# 6641        4.6                 9.0                   4.0
# 739         4.0                10.0                   3.0

# %%
#Connect to Local Database

rds_connection_string = "postgres:postgres@localhost:5432/ETL_project_movie_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Check for tables
engine.table_names()
# Out:
# ['IMBD_data', 'netflix_data', 'imbd_data']

# %%
### Use pandas to load csv converted DataFrame into database
IMBD_df.to_sql(name='imbd_data', con=engine, if_exists='append', index=False)

# %%
##Confirm data has been added by querying the netflix_data table
pd.read_sql_query('select * from imbd_data', con=engine).head()
# Out:
#          movie_title  year                     genre  duration  \
# 0     Kate & Leopold  2001  Comedy, Fantasy, Romance       118
# 1  The Naked Monster  2005    Comedy, Horror, Sci-Fi       100
# 2    The Fantasticks  2000          Musical, Romance        86
# 3      For the Cause  2000  Action, Adventure, Drama       100
# 4   The Silent Force  2001                    Action        90
#
#                      director  \
# 0               James Mangold
# 1   Wayne Berwick, Ted Newsom
# 2             Michael Ritchie
# 3  David Douglas, Tim Douglas
# 4                David H. May
#
#                                          description  avg_vote  \
# 0  An English Duke from 1876 is inadvertedly drag...       6.4
# 1  A brain-dead sheriff, a stolid secret agent an...       5.4
# 2  A mysterious fair that comes to a small commun...       5.6
# 3  Earth is in a state of constant war and two co...       3.5
# 4  An elite Federal force whose objective is to e...       4.3
#
#    reviews_from_users  reviews_from_critics
# 0               341.0                 115.0
# 1                15.0                   8.0
# 2                70.0                  24.0
# 3                 9.0                   7.0
# 4                 5.0                   4.0

# %%
#See how many movies by release year

IMBD__by_year_df = IMBD_df["year"].value_counts()
IMBD__by_year_df.head()
# Out:
# 2017    885
# 2016    839
# 2013    799
# 2014    787
# 2015    782
# Name: year, dtype: int64
