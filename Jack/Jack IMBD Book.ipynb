# %%
##Imports

import pandas as pd
from sqlalchemy import create_engine

# %%
##Store CSV into DataFrame

csv_file = "../Data/IMDb movies.csv"
IMBD_df = pd.read_csv(csv_file)
IMBD_df.sample(5)
# Out:
#       imdb_title_id             title    original_title  year date_published  \
# 74756     tt4465538         Juveniles         Juveniles  2018      8/28/2020
# 66679     tt2364975  We Are the Best!       Vi är bäst!  2013       6/5/2014
# 44863     tt0390649             Zhifu             Zhifu  2003      9/30/2003
# 83842     tt8159302       Luciérnagas       Luciérnagas  2018      12/6/2019
# 67144     tt2404552  Die Wonderwerker  Die Wonderwerker  2012       9/7/2012
#
#                  genre  duration                                  country  \
# 74756            Drama        88                                      USA
# 66679     Drama, Music       102                          Sweden, Denmark
# 44863  Drama, Thriller        94                         China, Hong Kong
# 83842            Drama        88  Mexico, USA, Greece, Dominican Republic
# 67144            Drama       119                             South Africa
#
#                         language         director  ...  \
# 74756                    English   Nico Sabenorio  ...
# 66679                    Swedish  Lukas Moodysson  ...
# 44863                   Mandarin      Yi'nan Diao  ...
# 83842  Spanish, English, Persian  Bani Khoshnoudi  ...
# 67144         Afrikaans, English    Katinka Heyns  ...
#
#                                                   actors  \
# 74756  Beau Knapp, Stephen Moyer, Jessica Rothe, Trev...
# 66679  Mira Barkhammar, Mira Grosin, Liv LeMoyne, Joh...
# 44863      Kai Han, Hongli Liang, Hua Qin, Xueqiong Zeng
# 83842  Arash Marandi, Edwarda Gurrola, Luis Alberti, ...
# 67144  Dawid Minnaar, Elize Cawood, Marius Weyers, An...
#
#                                              description avg_vote votes  \
# 74756  A college-bound teenager from the sticks fight...      5.9   137
# 66679  Three girls in 1980s Stockholm decide to form ...      7.2  9875
# 44863  Economic unrest roils central China's Shaanxi ...      6.4   215
# 83842  Ramin flees from persecution in Iran and ends ...      7.1   466
# 67144  Die Wonderwerker tells the story of Eugène Mar...      7.2   130
#
#        budget  usa_gross_income worlwide_gross_income metascore  \
# 74756     NaN               NaN                   NaN       NaN
# 66679     NaN         $180,590            $1,604,273       87.0
# 44863     NaN               NaN                   NaN       NaN
# 83842     NaN               NaN                   NaN       NaN
# 67144     NaN               NaN             $612,755        NaN
#
#       reviews_from_users  reviews_from_critics
# 74756                5.0                   NaN
# 66679               32.0                 160.0
# 44863                6.0                   8.0
# 83842                3.0                   5.0
# 67144                7.0                   2.0
#
# [5 rows x 22 columns]

# %%
##Read Columns

for col in IMBD_df.columns: 
    print(col)
# Out:
# imdb_title_id
# title
# original_title
# year
# date_published
# genre
# duration
# country
# language
# director
# writer
# production_company
# actors
# description
# avg_vote
# votes
# budget
# usa_gross_income
# worlwide_gross_income
# metascore
# reviews_from_users
# reviews_from_critics

# %%
##Cast year in to integer so to sort and drop
IMBD_df[['year']] = IMBD_df[['year']].apply(pd.to_numeric) 
print(IMBD_df.dtypes)
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                       int64
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
##Cast year in to integer so to sort and drop

IMBD_df = IMBD_df[(IMBD_df.country == "USA") & (IMBD_df.year > 1999) & (IMBD_df.year < 2018)] 
IMBD_df.sample(5)
# Out:
#       imdb_title_id                   title       original_title  year  \
# 60563     tt1663655                 Martyrs              Martyrs  2015
# 48331     tt0473500       Che bel pasticcio       Kettle of Fish  2006
# 62572     tt1845804           In the Family        In the Family  2011
# 70201     tt3179402  Moschettieri a 4 zampe  The Three Dogateers  2014
# 66340     tt2327243               Clubhouse            Clubhouse  2013
#
#       date_published                    genre  duration country language  \
# 60563      1/22/2016  Drama, Horror, Thriller        86     USA  English
# 48331      7/11/2006          Comedy, Romance        97     USA  English
# 62572      11/4/2011           Drama, Romance       169     USA  English
# 70201     11/11/2014                   Family        88     USA  English
# 66340     10/17/2013     Comedy, Crime, Drama        96     USA  English
#
#                          director  ...  \
# 60563  Kevin Goetz, Michael Goetz  ...
# 48331               Claudia Myers  ...
# 62572                Patrick Wang  ...
# 70201                 Jesse Baget  ...
# 66340              Yuri Shapochka  ...
#
#                                                   actors  \
# 60563  Troian Bellisario, Bailey Noble, Kate Burton, ...
# 48331  Matthew Modine, Gina Gershon, Christy Scott Ca...
# 62572  Sebastian Banes, Patrick Wang, Trevor St. John...
# 70201  Dean Cain, Richard Riehle, Bill Oberst Jr., Da...
# 66340  Tim Abell, Leslie Easterbrook, Christopher Mur...
#
#                                              description avg_vote votes  \
# 60563  A woman and her childhood friend seek out reve...      4.0  5163
# 48331  A lifelong bachelor confronts his intimacy iss...      5.2   644
# 62572  When his partner Cody dies in a car accident, ...      6.9   744
# 70201  When they are left on their own a few days bef...      3.1   254
# 66340  The movie is set in a stately old home in Birm...      6.6   771
#
#             budget  usa_gross_income worlwide_gross_income metascore  \
# 60563  $1,000,000                NaN             $397,072       22.0
# 48331  $2,000,000            $7,196                $7,196       38.0
# 62572          NaN         $101,934              $101,934       82.0
# 70201  $3,000,000                NaN                   NaN       NaN
# 66340          NaN               NaN                   NaN       NaN
#
#       reviews_from_users  reviews_from_critics
# 60563               73.0                 105.0
# 48331               22.0                   6.0
# 62572               11.0                  74.0
# 70201                7.0                   7.0
# 66340                5.0                   4.0
#
# [5 rows x 22 columns]

# %%
## Choose Columns,  drop rows where reviews_from_critics is NaN, remove duplicate movies
IMBD_df = IMBD_df.rename(columns={'title': 'movie_title'})
IMBD_df = IMBD_df[['movie_title', 'year', 'genre', 'duration', 'director', 'description', 'avg_vote', 'reviews_from_users', 'reviews_from_critics']].copy()

IMBD_df=IMBD_df.drop_duplicates(['movie_title'] , keep ='first') 

IMBD_df = IMBD_df.reset_index(drop=True)
IMBD_df.to_csv("../Output/IMBD_clean.csv")

IMBD_df.sample(10)
# Out:
#                                movie_title  year  \
# 7473                            Shark Week  2012
# 9932           Emoji - Accendi le emozioni  2017
# 9676                             40 Nights  2016
# 6416         My Trip Back to the Dark Side  2014
# 8040                       The Two Pamelas  2015
# 9546                         La babysitter  2017
# 5673               The Trouble with Terkel  2010
# 3193  La leggenda della montagna incantata  2010
# 7351                    The 6th Extinction  2012
# 2015                       The Ice Harvest  2005
#
#                              genre  duration  \
# 7473     Action, Adventure, Horror        89
# 9932  Animation, Adventure, Comedy        86
# 9676                         Drama        96
# 6416                      Thriller        94
# 8040         Crime, Drama, Mystery        91
# 9546                Comedy, Horror        85
# 5673      Animation, Comedy, Drama        87
# 3193    Animation, Family, Fantasy        92
# 7351                        Horror        90
# 2015          Comedy, Crime, Drama        92
#
#                                         director  \
# 7473                             Christopher Ray
# 9932                                Tony Leondis
# 9676                                   Jesse Low
# 6416                               Shane Stanley
# 8040                               Jeff Hathcock
# 9546                                         McG
# 5673  Thorbjørn Christoffersen, Stefan Fjeldmark
# 3193                             Steve Trenbirth
# 7351                                John Vincent
# 2015                                Harold Ramis
#
#                                             description  avg_vote  \
# 7473  A group of complete strangers find themselves ...       2.4
# 9932  Gene, a multi-expressional emoji, sets out on ...       3.3
# 9676  "40 Nights" is the first of the QUEST TRILOGY ...       3.1
# 6416  A dramatic turn of events forces Shawn Stone t...       4.4
# 8040  A young woman awakes on a casting directors co...       8.2
# 9546  The events of one evening take an unexpected t...       6.3
# 5673  Average teenager Terkel's life takes a turn fo...       7.1
# 3193  The legend of secret pass is a charming CGI an...       5.0
# 7351  It's day one of the end of the world, as vampi...       1.6
# 2015  A shady lawyer attempts a Christmas Eve crime,...       6.3
#
#       reviews_from_users  reviews_from_critics
# 7473                15.0                  25.0
# 9932               819.0                 158.0
# 9676                13.0                  15.0
# 6416                 5.0                   1.0
# 8040                 5.0                   1.0
# 9546               278.0                  85.0
# 5673                 3.0                   4.0
# 3193                10.0                   2.0
# 7351                15.0                   1.0
# 2015               165.0                 120.0

# %%
#Connect to Local Database

rds_connection_string = "postgres:postgres@localhost:5432/ETL_project_movie_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Check for tables
engine.table_names()
# Out:
# ['imbd_data', 'netflix_data']

# %%
### Use pandas to load csv converted DataFrame into database
IMBD_df.to_sql(name='imbd_data', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UniqueViolation: duplicate key value violates unique constraint "imbd_data_pkey"
# DETAIL:  Key (movie_title)=(Kate & Leopold) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-30-c84a32707d97> in <module>
#       1 ### Use pandas to load csv converted DataFrame into database
# ----> 2 IMBD_df.to_sql(name='imbd_data', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                             break
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "imbd_data_pkey"
# DETAIL:  Key (movie_title)=(Kate & Leopold) already exists.
#
# [SQL: INSERT INTO imbd_data (movie_title, year, genre, duration, director, description, avg_vote, reviews_from_users, reviews_from_critics) VALUES (%(movie_title)s, %(year)s, %(genre)s, %(duration)s, %(director)s, %(description)s, %(avg_vote)s, %(reviews_from_users)s, %(reviews_from_critics)s)]
# [parameters: ({'movie_title': 'Kate & Leopold', 'year': 2001, 'genre': 'Comedy, Fantasy, Romance', 'duration': 118, 'director': 'James Mangold', 'description': 'An English Duke from 1876 is inadvertedly dragged to modern day New York where he falls for a plucky advertising executive.', 'avg_vote': 6.4, 'reviews_from_users': 341.0, 'reviews_from_critics': 115.0}, {'movie_title': 'The Naked Monster', 'year': 2005, 'genre': 'Comedy, Horror, Sci-Fi', 'duration': 100, 'director': 'Wayne Berwick, Ted Newsom', 'description': 'A brain-dead sheriff, a stolid secret agent and a sexy scientist team with a grumpy retired monster fighter to battle a 60 foot, three-eyed cross between man and dinosaur.', 'avg_vote': 5.4, 'reviews_from_users': 15.0, 'reviews_from_critics': 8.0}, {'movie_title': 'The Fantasticks', 'year': 2000, 'genre': 'Musical, Romance', 'duration': 86, 'director': 'Michael Ritchie', 'description': 'A mysterious fair that comes to a small community in the countryside could make real the illusions of two teenagers.', 'avg_vote': 5.6, 'reviews_from_users': 70.0, 'reviews_from_critics': 24.0}, {'movie_title': 'For the Cause', 'year': 2000, 'genre': 'Action, Adventure, Drama', 'duration': 100, 'director': 'David Douglas, Tim Douglas', 'description': 'Earth is in a state of constant war and two colonies of humans have been sent to a far away world. The colonists create a new civilization but have inherited the worst traits of their ...', 'avg_vote': 3.5, 'reviews_from_users': 9.0, 'reviews_from_critics': 7.0}, {'movie_title': 'The Silent Force', 'year': 2001, 'genre': 'Action', 'duration': 90, 'director': 'David H. May', 'description': "An elite Federal force whose objective is to eliminate organized crime is violently assassinated by an evil Asian crime lord. The sole survivor of the group teams up with his late partner's...", 'avg_vote': 4.3, 'reviews_from_users': 5.0, 'reviews_from_critics': 4.0}, {'movie_title': 'What Is It?', 'year': 2005, 'genre': 'Drama', 'duration': 72, 'director': 'Crispin Glover', 'description': 'What Is It? is a bewildering, unnerving, surreal, blackly comic film from the visionary mind of Crispin Glover that tells the inner and outer struggles of a young man facing villains and demons on multiple planes.', 'avg_vote': 5.6, 'reviews_from_users': 19.0, 'reviews_from_critics': 18.0}, {'movie_title': 'Glitter', 'year': 2001, 'genre': 'Drama, Music, Romance', 'duration': 104, 'director': 'Vondie Curtis-Hall', 'description': 'A young singer dates a disc jockey who helps her get into the music business, but their relationship become complicated as she ascends to super stardom.', 'avg_vote': 2.2, 'reviews_from_users': 319.0, 'reviews_from_critics': 75.0}, {'movie_title': 'Horror in the Attic', 'year': 2001, 'genre': 'Comedy, Horror, Mystery', 'duration': 100, 'director': 'Jeremy Kasten', 'description': 'Trevor is a young man who has been sentenced to a long stay in a mental hospital after brutally killing his girlfriend. However, the longer Trevor is in stir, the more he wonders if the ...', 'avg_vote': 5.0, 'reviews_from_users': 65.0, 'reviews_from_critics': 22.0}  ... displaying 10 of 10696 total bound parameter sets ...  {'movie_title': 'Dimension Z', 'year': 2017, 'genre': 'Horror', 'duration': 70, 'director': 'Jarret Blinkhorn, Jesse H. Knight', 'description': 'When the zombie apocalypse arrives, groups of survivors band together to defend themselves at any cost. Unfortunately for the remaining few, zombies have evolved into different species ...', 'avg_vote': 6.6, 'reviews_from_users': 2.0, 'reviews_from_critics': None}, {'movie_title': 'House Shark', 'year': 2017, 'genre': 'Action, Adventure, Comedy', 'duration': 111, 'director': 'Ron Bonk', 'description': 'When he finds a shark that can travel on land residing in his home, an ex-cop enlists the help of a grizzled former real estate agent, and an eccentric "house shark" expert to kill the beast.', 'avg_vote': 4.8, 'reviews_from_users': 32.0, 'reviews_f ...
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
##Confirm data has been added by querying the netflix_data table
pd.read_sql_query('select * from imbd_data', con=engine).head()
# Out:
#          movie_title  year                     genre  duration  \
# 0     Kate & Leopold  2001  Comedy, Fantasy, Romance       118
# 1  The Naked Monster  2005    Comedy, Horror, Sci-Fi       100
# 2    The Fantasticks  2000          Musical, Romance        86
# 3      For the Cause  2000  Action, Adventure, Drama       100
# 4   The Silent Force  2001                    Action        90
#
#                      director  \
# 0               James Mangold
# 1   Wayne Berwick, Ted Newsom
# 2             Michael Ritchie
# 3  David Douglas, Tim Douglas
# 4                David H. May
#
#                                          description  avg_vote  \
# 0  An English Duke from 1876 is inadvertedly drag...       6.4
# 1  A brain-dead sheriff, a stolid secret agent an...       5.4
# 2  A mysterious fair that comes to a small commun...       5.6
# 3  Earth is in a state of constant war and two co...       3.5
# 4  An elite Federal force whose objective is to e...       4.3
#
#    reviews_from_users  reviews_from_critics
# 0               341.0                 115.0
# 1                15.0                   8.0
# 2                70.0                  24.0
# 3                 9.0                   7.0
# 4                 5.0                   4.0

# %%
#See how many movies by release year

IMBD__by_year_df = IMBD_df["year"].value_counts()
IMBD__by_year_df.head()
# Out:
# 2017    885
# 2016    839
# 2013    799
# 2014    787
# 2015    782
# Name: year, dtype: int64
