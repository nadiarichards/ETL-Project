# %%
##Imports

import pandas as pd
from sqlalchemy import create_engine

# %%
##Store CSV into DataFrame

csv_file = "../Data/IMDb movies.csv"
IMBD_df = pd.read_csv(csv_file)
IMBD_df.sample(5)
# Out:
#       imdb_title_id                      title             original_title  \
# 18176     tt0076666  La febbre del sabato sera       Saturday Night Fever
# 6015      tt0040868   Texas, Brooklyn & Heaven   Texas, Brooklyn & Heaven
# 16474     tt0071330    Il cittadino si ribella    Il cittadino si ribella
# 3046      tt0030442            Gioia di vivere            Merrily We Live
# 23539     tt0093996  Slumber Party Massacre II  Slumber Party Massacre II
#
#        year date_published                  genre  duration country  \
# 18176  1977      3/13/1978           Drama, Music       118     USA
# 6015   1948      7/16/1948        Comedy, Romance        76     USA
# 16474  1974      9/17/1974       Action, Thriller       105   Italy
# 3046   1938       3/4/1938        Comedy, Romance        95     USA
# 23539  1987     10/16/1987  Comedy, Horror, Music        77     USA
#
#                language            director  ...  \
# 18176  English, Italian         John Badham  ...
# 6015            English      William Castle  ...
# 16474  English, Italian  Enzo G. Castellari  ...
# 3046            English    Norman Z. McLeod  ...
# 23539           English       Deborah Brock  ...
#
#                                                   actors  \
# 18176  John Travolta, Karen Lynn Gorney, Barry Miller...
# 6015   Guy Madison, Diana Lynn, James Dunn, Michael C...
# 16474  Franco Nero, Giancarlo Prete, Barbara Bach, Re...
# 3046   Constance Bennett, Brian Aherne, Alan Mowbray,...
# 23539  Crystal Bernard, Jennifer Rhodes, Kimberly McA...
#
#                                              description avg_vote  votes  \
# 18176  Anxious about his future after high school, a ...      6.8  69620
# 6015   A would-be playwright and a young woman escapi...      6.2    282
# 16474  Carlo Antonelli, an engineer from Genoa, gets ...      7.0   1219
# 3046   Dizzy society matron Emily Kilbourne has a hab...      7.4   1525
# 23539  Courtney Bates, the younger sister of Valerie,...      4.6   4443
#
#             budget  usa_gross_income worlwide_gross_income metascore  \
# 18176  $3,000,000       $94,213,184          $237,113,184       77.0
# 6015   $1,000,000                NaN                   NaN       NaN
# 16474          NaN               NaN                   NaN       NaN
# 3046           NaN               NaN                   NaN       NaN
# 23539          NaN               NaN                   NaN       NaN
#
#       reviews_from_users  reviews_from_critics
# 18176              256.0                 103.0
# 6015                12.0                   1.0
# 16474               24.0                  44.0
# 3046                53.0                  15.0
# 23539               95.0                  81.0
#
# [5 rows x 22 columns]

# %%
##Read Columns

for col in IMBD_df.columns: 
    print(col)
# Out:
# imdb_title_id
# title
# original_title
# year
# date_published
# genre
# duration
# country
# language
# director
# writer
# production_company
# actors
# description
# avg_vote
# votes
# budget
# usa_gross_income
# worlwide_gross_income
# metascore
# reviews_from_users
# reviews_from_critics

# %%
##Cast year in to integer so to sort and drop
IMBD_df[['year']] = IMBD_df[['year']].apply(pd.to_numeric) 
print(IMBD_df.dtypes)
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                       int64
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
##Cast year in to integer so to sort and drop

IMBD_df = IMBD_df[(IMBD_df.country == "USA") & (IMBD_df.year > 1999) & (IMBD_df.year < 2018)] 
IMBD_df.sample(5)
# Out:
#       imdb_title_id                  title         original_title  year  \
# 70726     tt3311988           The Confines           The Confines  2015
# 41184     tt0302886             Old School             Old School  2003
# 51709     tt0946984  A Bothered Conscience  A Bothered Conscience  2006
# 40803     tt0294881     Role of a Lifetime     Role of a Lifetime  2002
# 61807     tt1772321          Noise Matters          Noise Matters  2013
#
#       date_published                      genre  duration country language  \
# 70726      6/13/2015  Horror, Mystery, Thriller        86     USA  English
# 41184       8/8/2003                     Comedy        88     USA  English
# 51709     10/22/2006                     Horror        87     USA  English
# 40803       2/5/2002                      Drama        98     USA  English
# 61807      3/15/2013       Comedy, Drama, Music        88     USA  English
#
#                   director  ...  \
# 70726       Eytan Rockaway  ...
# 41184        Todd Phillips  ...
# 51709  Dennis Smithers Jr.  ...
# 40803          Antony Alda  ...
# 61807       Matias Masucci  ...
#
#                                                   actors  \
# 70726  Jason Patric, Louisa Krause, Mark Margolis, Ez...
# 41184  Luke Wilson, Will Ferrell, Vince Vaughn, Jerem...
# 51709  Dennis Smithers Sr., Stephen Martin, MacFarlan...
# 40803  Scott Bakula, Edie Dearing, Beverly Taylor, Ma...
# 61807  Matias Masucci, Ugo Bianchi, Bret Roberts, Joe...
#
#                                              description avg_vote   votes  \
# 70726  Take a terrifying plunge into the warped mind ...      5.0    4093
# 41184  Three friends attempt to recapture their glory...      7.1  211665
# 51709  In the backwoods of Arkansas, a father and son...      4.2     158
# 40803  A has-been actor drops from public view and is...      5.4     131
# 61807  A satire on the relationship between fame and ...      7.0     152
#
#              budget  usa_gross_income worlwide_gross_income metascore  \
# 70726           NaN               NaN                   NaN      32.0
# 41184  $24,000,000       $75,585,093           $87,135,520       54.0
# 51709       $2,300                NaN                   NaN       NaN
# 40803           NaN               NaN                   NaN       NaN
# 61807     $100,000                NaN                   NaN       NaN
#
#       reviews_from_users  reviews_from_critics
# 70726               47.0                  43.0
# 41184              408.0                 119.0
# 51709               11.0                   7.0
# 40803                3.0                   NaN
# 61807                1.0                   3.0
#
# [5 rows x 22 columns]
