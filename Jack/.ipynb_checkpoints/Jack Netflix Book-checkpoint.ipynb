# %%
##Imports
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy import create_engine

# %%
##Store CSV into DataFrame

csv_file = "../Data/Netflix_titles.csv"
netflix_df = pd.read_csv(csv_file)
netflix_df.sample(5)
# Out:
#      show_id     type                              title  \
# 4940   s7127    Movie  Todo lo que sería Lucas Lauriente
# 7284   s6259  TV Show               The Cuba Libre Story
# 5603    s903  TV Show           Big Dreams, Small Spaces
# 2459   s3509    Movie                              Laatu
# 4160   s5989    Movie                             Tarzan
#
#                     director  \
# 4940  Raúl Campos, Jan Suter
# 7284                     NaN
# 5603                     NaN
# 2459              Manav Shah
# 4160  Chris Buck, Kevin Lima
#
#                                                    cast          country  \
# 4940                                    Lucas Lauriente        Argentina
# 7284                                                NaN  France, Germany
# 5603                                          Monty Don   United Kingdom
# 2459  Gagan Kokri, Aditi Sharma, Karamjit Anmol, Sar...            India
# 4160  Tony Goldwyn, Minnie Driver, Glenn Close, Bria...    United States
#
#           date_added  release_year rating   duration  \
# 4940        6-Apr-18          2018  TV-MA     78 min
# 7284        8-Dec-16          2015  TV-14   1 Season
# 5603   July 26, 2019          2017   TV-G  3 Seasons
# 2459        2-May-19          2018  TV-PG    116 min
# 4160       23-Jun-18          1999      G     89 min
#
#                                               listed_in  \
# 4940                                    Stand-Up Comedy
# 7284                 Docuseries, International TV Shows
# 5603  British TV Shows, International TV Shows, Real...
# 2459             Comedies, Dramas, International Movies
# 4160                           Children & Family Movies
#
#                                             description
# 4940  In his stand-up set, Argentine comic Lucas Lau...
# 7284  This documentary series recounts the tumultuou...
# 5603  Writer and presenter Monty Don helps England's...
# 2459  A man who hopes to bring light to his village ...
# 4160  After being shipwrecked off the African coast,...

# %%
##Read Columns

for col in netflix_df.columns: 
    print(col)
# Out:
# show_id
# type
# title
# director
# cast
# country
# date_added
# release_year
# rating
# duration
# listed_in
# description

# %%
##Drop all non-Movies and only capture U.S, and movies 2000-2017
netflix_df = netflix_df[(netflix_df.type == "Movie") & (netflix_df.release_year > 1999) & (netflix_df.release_year < 2018)] 
netflix_df.sample(10)
# Out:
#      show_id   type                         title  \
# 4016   s5768  Movie   Spookley the Square Pumpkin
# 2834   s4069  Movie           Michael Che Matters
# 4177   s6011  Movie                    Teen Patti
# 1459   s2080  Movie               Eyyvah Eyyvah 2
# 3072   s4417  Movie  Natalia Valdebenito: Gritona
# 3080   s4425  Movie             National Treasure
# 3013   s4322  Movie               My Happy Family
# 3839   s5505  Movie                       Set Off
# 2136   s3076  Movie    It Takes a Man and a Woman
# 3897   s5580  Movie                       Shorgul
#
#                              director  \
# 4016                      Bernie Denk
# 2834                     Oz Rodriguez
# 4177                      Leena Yadav
# 1459                      Hakan Algül
# 3072              Natalia Valdebenito
# 3080                   Jon Turteltaub
# 3013  Nana Ekvtimishvili, Simon Gross
# 3839                        Liu Jiang
# 2136              Cathy Garcia-Molina
# 3897    Jitendra Tiwari, Pranav Singh
#
#                                                    cast  \
# 4016  Sonja Ball, Craig Francis, Rick Jones, Michel ...
# 2834                                        Michael Che
# 4177  Amitabh Bachchan, Madhavan, Ben Kingsley, Shra...
# 1459  Demet Akbağ, Ata Demirer, Özge Borak, Salih Ka...
# 3072                                Natalia Valdebenito
# 3080  Nicolas Cage, Diane Kruger, Justin Bartha, Sea...
# 3013  Ia Shugliashvili, Merab Ninidze, Berta Khapava...
# 3839  Wenpei Ju, Fan Wei, Liu Hua, Qianyuan Wang, Re...
# 2136  John Lloyd Cruz, Sarah Geronimo, Rowell Santia...
# 3897  Ashutosh Rana, Jimmy Shergill, Suha Gezen, San...
#
#                        country date_added  release_year rating duration  \
# 4016             United States   1-Sep-19          2004      G   47 min
# 2834             United States  25-Nov-16          2016  TV-MA   61 min
# 4177                     India   1-Mar-18          2010  TV-PG  137 min
# 1459                    Turkey  10-Mar-17          2011  TV-PG  106 min
# 3072             United States  10-Nov-17          2017  TV-MA   76 min
# 3080             United States   1-Jun-18          2004     PG  131 min
# 3013  Georgia, Germany, France   1-Dec-17          2017  TV-14  119 min
# 3839                     China   1-Dec-18          2008  TV-MA   96 min
# 2136               Philippines  27-Feb-19          2013  TV-PG  127 min
# 3897                     India  30-Oct-18          2016  TV-14  122 min
#
#                                              listed_in  \
# 4016                          Children & Family Movies
# 2834                                   Stand-Up Comedy
# 4177           Dramas, International Movies, Thrillers
# 1459   Comedies, International Movies, Romantic Movies
# 3072                                   Stand-Up Comedy
# 3080      Action & Adventure, Children & Family Movies
# 3013  Dramas, Independent Movies, International Movies
# 3839                      Dramas, International Movies
# 2136   Comedies, International Movies, Romantic Movies
# 3897                      Dramas, International Movies
#
#                                             description
# 4016  When a storm terrorizes his patch, a pumpkin c...
# 2834  "SNL" star Michael Che takes on hot-button top...
# 4177  Luck brings together math expert Perci Trachte...
# 1459  Hüseyin has found his father, and now has one ...
# 3072  Chile's Natalia Valdebenito hits Santiago's Te...
# 3080  Modern treasure hunters search for a chest of ...
# 3013  A middle-aged wife and mother of two shocks he...
# 3839  When a restaurant owner in Cyprus returns to B...
# 2136  Laida and Miggy used to be in love, but now th...
# 3897  A Hindu boy's feelings for a Muslim girl expos...

# %%
##Choose Columns, rename 

clean_netflix_df = netflix_df[['title', 'director', 'cast', 'release_year', 'rating', 'duration', 'listed_in', 'description']].copy()
clean_netflix_df = clean_netflix_df.rename(columns={'title': 'movie_title', 'cast': 'actors'})
clean_netflix_df = clean_netflix_df.drop_duplicates(subset='movie_title', keep='first')

clean_netflix_df=clean_netflix_df.drop_duplicates(['movie_title'] , keep ='first') 

clean_netflix_df = clean_netflix_df.reset_index(drop=True)

clean_netflix_df.to_csv("../Output/Netflix_clean.csv")

clean_netflix_df.head(5)
# Out:
#   movie_title           director  \
# 0        7:19  Jorge Michel Grau
# 1       23:59       Gilbert Chan
# 2           9        Shane Acker
# 3          21     Robert Luketic
# 4        1920       Vikram Bhatt
#
#                                               actors  release_year rating  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...          2016  TV-MA
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...          2011      R
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...          2009  PG-13
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          2008  PG-13
# 4  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...          2008  TV-MA
#
#   duration                                          listed_in  \
# 0   93 min                       Dramas, International Movies
# 1   78 min                Horror Movies, International Movies
# 2   80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 3  123 min                                             Dramas
# 4  143 min     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  After a devastating earthquake hits Mexico Cit...
# 1  When an army recruit is found dead, his fellow...
# 2  In a postapocalyptic world, rag-doll robots hi...
# 3  A brilliant group of students become card-coun...
# 4  An architect and his wife move into a castle t...

# %%
#Connect to Local Database

rds_connection_string = "postgres:postgres@localhost:5432/ETL_project_movie_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Check for tables
engine.table_names()
# Out:
# ['imbd_data', 'netflix_data']

# %%
### Use pandas to load csv converted DataFrame into database
clean_netflix_df.to_sql(name='netflix_data', con=engine, if_exists='append', index=False)

# %%
##Confirm data has been added by querying the netflix_data table
pd.read_sql_query('select * from netflix_data', con=engine).head()
# Out:
#   movie_title  year           director  \
# 0        7:19  None  Jorge Michel Grau
# 1       23:59  None       Gilbert Chan
# 2           9  None        Shane Acker
# 3          21  None     Robert Luketic
# 4        1920  None       Vikram Bhatt
#
#                                               actors  release_year rating  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...          2016  TV-MA
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...          2011      R
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...          2009  PG-13
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          2008  PG-13
# 4  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...          2008  TV-MA
#
#   duration                                          listed_in  \
# 0   93 min                       Dramas, International Movies
# 1   78 min                Horror Movies, International Movies
# 2   80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 3  123 min                                             Dramas
# 4  143 min     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  After a devastating earthquake hits Mexico Cit...
# 1  When an army recruit is found dead, his fellow...
# 2  In a postapocalyptic world, rag-doll robots hi...
# 3  A brilliant group of students become card-coun...
# 4  An architect and his wife move into a castle t...

# %%
#See how many movies by release year

netflix_by_year = clean_netflix_df["release_year"].value_counts()
netflix_by_year.head()
# Out:
# 2017    744
# 2016    642
# 2015    382
# 2014    244
# 2013    202
# Name: release_year, dtype: int64

# %%
#See how many movies by Rating

netflix_by_year = clean_netflix_df["rating"].value_counts()
netflix_by_year.head()
# Out:
# TV-MA    997
# TV-14    779
# R        462
# TV-PG    298
# PG-13    275
# Name: rating, dtype: int64
