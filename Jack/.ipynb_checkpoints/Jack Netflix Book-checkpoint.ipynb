# %%
##Imports
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy import create_engine

# %%
##Store CSV into DataFrame

csv_file = "../Data/Netflix_titles.csv"
netflix_df = pd.read_csv(csv_file)
netflix_df.sample(5)
# Out:
#      show_id   type                                             title  \
# 3793   s5440  Movie                    Scorpion King 5: Book of Souls
# 3051   s4385  Movie                             Naga The Eternal Yogi
# 4729   s6823  Movie                                          The Ring
# 3637   s5241  Movie                                             Rocco
# 999    s1381  Movie  ChuChuTV Surprise Eggs Learning Videos (English)
#
#                                director  \
# 3793                   Don Michael Paul
# 3051   Krishna Agazzi, Filippo Gastaldi
# 4729                     Gore Verbinski
# 3637  Thierry Demaizière, Alban Teurlai
# 999                                 NaN
#
#                                                    cast        country  \
# 3793  Zach McGowan, Pearl Thusi, Nathan Jones, Peter...  United States
# 3051                                                NaN   Italy, India
# 4729  Naomi Watts, Martin Henderson, David Dorfman, ...  United States
# 3637                                     Rocco Siffredi         France
# 999                                                 NaN            NaN
#
#      date_added  release_year rating duration  \
# 3793  23-Oct-18          2018  PG-13  102 min
# 3051   5-Feb-17          2016  TV-PG   73 min
# 4729   1-Jan-20          2002  PG-13  116 min
# 3637   1-Sep-17          2016  TV-MA  103 min
# 999   18-Oct-19          2019   TV-Y   61 min
#
#                                  listed_in  \
# 3793  Action & Adventure, Sci-Fi & Fantasy
# 3051   Documentaries, International Movies
# 4729              Horror Movies, Thrillers
# 3637   Documentaries, International Movies
# 999               Children & Family Movies
#
#                                             description
# 3793  The Scorpion King joins forces with a Nubian p...
# 3051  This documentary examines the naked yoga gurus...
# 4729  A reporter watches a video that supposedly set...
# 3637  Italian porn star Rocco Siffredi is showcased ...
# 999   From colors and letters to animals of all kind...

# %%
##Read Columns

for col in netflix_df.columns: 
    print(col)
# Out:
# show_id
# type
# title
# director
# cast
# country
# date_added
# release_year
# rating
# duration
# listed_in
# description

# %%
##Drop all non-Movies and only capture U.S, and movies 2000-2017
netflix_df = netflix_df[(netflix_df.type == "Movie") & (netflix_df.release_year > 1999) & (netflix_df.release_year < 2018)] 
netflix_df.sample(10)
# Out:
#      show_id   type                                          title  \
# 3351   s4814  Movie                                    Peepli Live
# 499     s653  Movie                                      B.A. Pass
# 4583   s6617  Movie  The Lord of the Rings: The Return of the King
# 4941   s7128  Movie                            Todo Sobre El Asado
# 5119   s7409  Movie                               Verses of Love 2
# 4697   s6776  Movie                                     The Prince
# 3696   s5315  Movie                      Russell Peters: Notorious
# 2372   s3377  Movie                              Kill Bill: Vol. 2
# 3796   s5444  Movie                                       Scream 3
# 1509   s2160  Movie                              Figures of Speech
#
#                             director  \
# 3351  Anusha Rizvi, Mahmood Farooqui
# 499                        Ajay Bahl
# 4583                   Peter Jackson
# 4941     Mariano Cohn, Gastón Duprat
# 5119              Guntur Soeharjanto
# 4697                 Brian A. Miller
# 3696                      Dave Higby
# 2372               Quentin Tarantino
# 3796                      Wes Craven
# 1509                    Ari Levinson
#
#                                                    cast  \
# 3351  Omkar Das Manikpuri, Raghuvir Yadav, Malaika S...
# 499   Shadab Kamal, Shilpa Shukla, Rajesh Sharma, Di...
# 4583  Elijah Wood, Ian McKellen, Liv Tyler, Viggo Mo...
# 4941                                   El Negro Álvarez
# 5119  Fedi Nuril, Tatjana Saphira, Dewi Sandra, Chel...
# 4697  Jason Patric, Bruce Willis, John Cusack, Rain,...
# 3696                                     Russell Peters
# 2372  Uma Thurman, David Carradine, Michael Madsen, ...
# 3796  David Arquette, Neve Campbell, Courteney Cox, ...
# 1509                                         Chris Pine
#
#                             country date_added  release_year rating duration  \
# 3351                          India  10-Jan-21          2010  TV-MA  109 min
# 499                           India   7-Jun-18          2013  TV-14   99 min
# 4583     New Zealand, United States   1-Jan-20          2003  PG-13  201 min
# 4941                      Argentina   1-Sep-17          2016  TV-MA   86 min
# 5119                      Indonesia  18-Oct-19          2017  TV-14  127 min
# 4697  United States, United Kingdom  22-Feb-19          2014      R   91 min
# 3696                  United States  14-Oct-13          2013     NR   72 min
# 2372                  United States   1-Jan-20          2004      R  137 min
# 3796                  United States   1-Jul-19          2000      R  117 min
# 1509                  United States  21-Dec-16          2016  TV-PG   92 min
#
#                                               listed_in  \
# 3351               Comedies, Dramas, Independent Movies
# 499    Dramas, Independent Movies, International Movies
# 4583               Action & Adventure, Sci-Fi & Fantasy
# 4941                Documentaries, International Movies
# 5119  Dramas, Faith & Spirituality, International Mo...
# 4697                                 Action & Adventure
# 3696                                    Stand-Up Comedy
# 2372                                 Action & Adventure
# 3796                                      Horror Movies
# 1509                                      Documentaries
#
#                                             description
# 3351  Two indigent farmers consider suicide so that ...
# 499   Orphaned and at loose ends, young Mukesh falls...
# 4583  Aragorn is revealed as the heir to the ancient...
# 4941  This quirky examination of Argentina's culture...
# 5119  Now a lecturer in Edinburgh, Fahri tries to be...
# 4697  A former Mafia hit man living quietly as a mec...
# 3696  Global comedy star Russell Peters leaves no et...
# 2372  The Bride has three left on her rampage list: ...
# 3796  This installment of the tongue-in-cheek horror...
# 1509  In this documentary, passionate high schoolers...

# %%
##Choose Columns

clean_netflix_df = netflix_df[['title', 'director', 'cast', 'release_year', 'rating', 'duration', 'listed_in', 'description']].copy()
clean_netflix_df = clean_netflix_df.rename(columns={'title': 'movie_title'})

clean_netflix_df = clean_netflix_df.reset_index(drop=True)
clean_netflix_df.head(5)

clean_netflix_df.to_csv("../Output/Netflix_clean.csv")

# %%
#Connect to Local Database

rds_connection_string = "postgres:postgres@localhost:5432/ETL_project_movie_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Check for tables
engine.table_names()
# Out:
# ['IMBD_data', 'netflix_data', 'imbd_data']

# %%
### Use pandas to load csv converted DataFrame into database
clean_netflix_df.to_sql(name='netflix_data', con=engine, if_exists='append', index=False)

# %%
##Confirm data has been added by querying the netflix_data table
pd.read_sql_query('select * from netflix_data', con=engine).head()
# Out:
#   movie_title           director  \
# 0        7:19  Jorge Michel Grau
# 1       23:59       Gilbert Chan
# 2           9        Shane Acker
# 3          21     Robert Luketic
# 4        1920       Vikram Bhatt
#
#                                                 cast  release_year rating  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...          2016  TV-MA
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...          2011      R
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...          2009  PG-13
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          2008  PG-13
# 4  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...          2008  TV-MA
#
#   duration                                          listed_in  \
# 0   93 min                       Dramas, International Movies
# 1   78 min                Horror Movies, International Movies
# 2   80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 3  123 min                                             Dramas
# 4  143 min     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  After a devastating earthquake hits Mexico Cit...
# 1  When an army recruit is found dead, his fellow...
# 2  In a postapocalyptic world, rag-doll robots hi...
# 3  A brilliant group of students become card-coun...
# 4  An architect and his wife move into a castle t...

# %%
#See how many movies by release year

netflix_by_year = clean_netflix_df["release_year"].value_counts()
netflix_by_year.head()
# Out:
# 2017    744
# 2016    642
# 2015    382
# 2014    244
# 2013    202
# Name: release_year, dtype: int64

# %%
#See how many movies by Rating

netflix_by_year = clean_netflix_df["rating"].value_counts()
netflix_by_year.head()
# Out:
# TV-MA    997
# TV-14    779
# R        462
# TV-PG    298
# PG-13    275
# Name: rating, dtype: int64
