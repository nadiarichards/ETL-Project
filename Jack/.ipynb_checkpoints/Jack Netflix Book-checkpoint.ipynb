# %%
##Imports
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy import create_engine

# %%
##Store CSV into DataFrame

csv_file = "../Data/Netflix_titles.csv"
netflix_df = pd.read_csv(csv_file)
netflix_df.sample(5)
# Out:
#      show_id   type                     title             director  \
# 1636   s2335  Movie       Gaddar: the Traitor          Amitoj Mann
# 123     s158  Movie                    A Choo  Kevin Ko, Peter Tsi
# 4966   s7164  Movie  Tottaa Pataaka Item Maal     Aditya Kripalani
# 1981   s2855  Movie                Hridaynath           Amar Gupte
# 767    s1030  Movie         Bollywood Calling      Nagesh Kukunoor
#
#                                                    cast country date_added  \
# 1636  Harbhajan Mann, Manpneet Grewal, Ashish Duggal...   India   1-Nov-18
# 123   Kai Ko, Ariel Lin, Darren Wang, Zhang Xiaolong...  Taiwan  14-Oct-20
# 4966  Shalini Vatsa, Chitrangada Chakraborty, Vinay ...   India  25-Jun-19
# 1981  Jackie Shroff, Aditya Pancholi, Swarangi Mahar...   India   1-Jan-18
# 767   Om Puri, Pat Cusick, Navin Nischol, Perizaad Z...   India  15-Apr-19
#
#       release_year rating duration  \
# 1636          2015  TV-14  126 min
# 123           2020  TV-14  101 min
# 4966          2018  TV-MA  107 min
# 1981          2012  TV-14  103 min
# 767           2001  TV-MA  102 min
#
#                                               listed_in  \
# 1636            Dramas, International Movies, Thrillers
# 123   Action & Adventure, International Movies, Roma...
# 4966   Dramas, Independent Movies, International Movies
# 1981                       Dramas, International Movies
# 767              Comedies, Dramas, International Movies
#
#                                             description
# 1636  An Indian man who has become a major business ...
# 123   Determined to win the heart of his childhood c...
# 4966  Exasperated with living in perpetual fear for ...
# 1981  A schoolteacher known for his good deeds and b...
# 767   A down-and-out Hollywood actor is utterly unpr...

# %%
##Read Columns

for col in netflix_df.columns: 
    print(col)
# Out:
# show_id
# type
# title
# director
# cast
# country
# date_added
# release_year
# rating
# duration
# listed_in
# description

# %%
##Drop all non-Movies and only capture U.S, and movies 2000-2017
netflix_df = netflix_df[(netflix_df.type == "Movie") & (netflix_df.release_year > 1999) & (netflix_df.release_year < 2018)] 
netflix_df.sample(10)
# Out:
#      show_id   type                                              title  \
# 1313   s1863  Movie                   Dream Big: Engineering Our World
# 387     s497  Movie                                    An Ordinary Man
# 2280   s3258  Movie             Justin Timberlake + the Tennessee Kids
# 346     s445  Movie                                               Amar
# 1002   s1385  Movie                                      Chupan Chupai
# 380     s489  Movie  An American Tail: The Treasures of Manhattan I...
# 4754   s6855  Movie                       The Search for Life in Space
# 4998   s7215  Movie                                Trespass Against Us
# 2948   s4240  Movie                                   Motor Mitraan Di
# 3147   s4526  Movie                         NOVA: Death Dive to Saturn
#
#                director                                               cast  \
# 1313  Greg MacGillivray                                       Jeff Bridges
# 387     Brad Silberling      Ben Kingsley, Hera Hilmar, Peter Serafinowicz
# 2280     Jonathan Demme                                  Justin Timberlake
# 346      Esteban Crespo  María Pedraza, Pol Monen, Natalia Tena, Nacho ...
# 1002         Mohsin Ali  Ahsan Khan, Neelam Muneer, Faizan Khawaja, Ali...
# 380        Larry Latham  Thomas Dekker, Dom DeLuise, Pat Musick, Nehemi...
# 4754   Stephen Amezdroz                                                NaN
# 4998         Adam Smith  Michael Fassbender, Brendan Gleeson, Lyndsey M...
# 2948        Amitoj Mann  Gurpreet Guggi, Happy Raikoti, Vikram Singh, S...
# 3147      Terri Randall                                      Craig Sechler
#
#                     country date_added  release_year rating duration  \
# 1313          United States   1-Jul-18          2017   TV-G   42 min
# 387   Serbia, United States   1-Oct-20          2017      R   91 min
# 2280          United States  12-Oct-16          2016  TV-MA   90 min
# 346                   Spain  15-Jul-17          2017  TV-MA  104 min
# 1002               Pakistan  15-Jan-19          2017  TV-14  118 min
# 380           United States   1-Apr-18          2000      G   79 min
# 4754          United States   1-Apr-18          2016   TV-G   32 min
# 4998         United Kingdom  22-Feb-19          2016      R  100 min
# 2948                  India   1-Oct-18          2016  TV-PG  117 min
# 3147          United States   1-Jul-19          2017   TV-G   54 min
#
#                                           listed_in  \
# 1313                                  Documentaries
# 387                               Dramas, Thrillers
# 2280                               Music & Musicals
# 346   Dramas, International Movies, Romantic Movies
# 1002                 Comedies, International Movies
# 380                        Children & Family Movies
# 4754                                  Documentaries
# 4998                                         Dramas
# 2948                 Comedies, International Movies
# 3147                                  Documentaries
#
#                                             description
# 1313  Narrated by Jeff Bridges, this compelling docu...
# 387   A war criminal in hiding begins to suspect tha...
# 2280  On the final nights of a world tour, director ...
# 346   Young Laura and Carlos experience the intensit...
# 1002  The lives of five hapless, petty criminals car...
# 380   When Fievel and friends go hunting for buried ...
# 4754  To determine whether we're alone in the univer...
# 4998  A man from a criminal family yearns to break a...
# 2948  When three brothers unwittingly get entangled ...
# 3147  After decades of amazing discoveries, spacecra...

# %%
##Choose Columns, rename 

clean_netflix_df = netflix_df[['title', 'director', 'cast', 'release_year', 'rating', 'duration', 'listed_in', 'description']].copy()
clean_netflix_df = clean_netflix_df.rename(columns={'title': 'movie_title'})
clean_netflix_df = clean_netflix_df.drop_duplicates(subset='movie_title', keep='first')

clean_netflix_df=clean_netflix_df.drop_duplicates(['movie_title'] , keep ='first') 

clean_netflix_df = clean_netflix_df.reset_index(drop=True)

clean_netflix_df.to_csv("../Output/Netflix_clean.csv")

clean_netflix_df.head(5)
# Out:
#   movie_title           director  \
# 0        7:19  Jorge Michel Grau
# 1       23:59       Gilbert Chan
# 2           9        Shane Acker
# 3          21     Robert Luketic
# 4        1920       Vikram Bhatt
#
#                                                 cast  release_year rating  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...          2016  TV-MA
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...          2011      R
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...          2009  PG-13
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          2008  PG-13
# 4  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...          2008  TV-MA
#
#   duration                                          listed_in  \
# 0   93 min                       Dramas, International Movies
# 1   78 min                Horror Movies, International Movies
# 2   80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 3  123 min                                             Dramas
# 4  143 min     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  After a devastating earthquake hits Mexico Cit...
# 1  When an army recruit is found dead, his fellow...
# 2  In a postapocalyptic world, rag-doll robots hi...
# 3  A brilliant group of students become card-coun...
# 4  An architect and his wife move into a castle t...

# %%
#Connect to Local Database

rds_connection_string = "postgres:postgres@localhost:5432/ETL_project_movie_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Check for tables
engine.table_names()
# Out:
# ['IMBD_data', 'netflix_data', 'imbd_data']

# %%
### Use pandas to load csv converted DataFrame into database
clean_netflix_df.to_sql(name='netflix_data', con=engine, if_exists='append', index=False)

# %%
##Confirm data has been added by querying the netflix_data table
pd.read_sql_query('select * from netflix_data', con=engine).head()
# Out:
#   movie_title           director  \
# 0        7:19  Jorge Michel Grau
# 1       23:59       Gilbert Chan
# 2           9        Shane Acker
# 3          21     Robert Luketic
# 4        1920       Vikram Bhatt
#
#                                                 cast  release_year rating  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...          2016  TV-MA
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...          2011      R
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...          2009  PG-13
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          2008  PG-13
# 4  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...          2008  TV-MA
#
#   duration                                          listed_in  \
# 0   93 min                       Dramas, International Movies
# 1   78 min                Horror Movies, International Movies
# 2   80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 3  123 min                                             Dramas
# 4  143 min     Horror Movies, International Movies, Thrillers
#
#                                          description
# 0  After a devastating earthquake hits Mexico Cit...
# 1  When an army recruit is found dead, his fellow...
# 2  In a postapocalyptic world, rag-doll robots hi...
# 3  A brilliant group of students become card-coun...
# 4  An architect and his wife move into a castle t...

# %%
#See how many movies by release year

netflix_by_year = clean_netflix_df["release_year"].value_counts()
netflix_by_year.head()
# Out:
# 2017    744
# 2016    642
# 2015    382
# 2014    244
# 2013    202
# Name: release_year, dtype: int64

# %%
#See how many movies by Rating

netflix_by_year = clean_netflix_df["rating"].value_counts()
netflix_by_year.head()
# Out:
# TV-MA    997
# TV-14    779
# R        462
# TV-PG    298
# PG-13    275
# Name: rating, dtype: int64
