# %%
##Imports

import pandas as pd
from sqlalchemy import create_engine

# %%
##Store CSV into DataFrame

csv_file = "../Data/IMDb movies.csv"
IMBD_df = pd.read_csv(csv_file)
IMBD_df.sample(5)
# Out:
#       imdb_title_id                                            title  \
# 9591      tt0051790                          La congiura dei boiardi
# 53482    tt10735778                                     Nashi Kotyky
# 38069     tt0246514                             Solo per il successo
# 17397     tt0074348                       Il cadavere del mio nemico
# 71603     tt3525168  Morto tra una settimana... O ti ridiamo i soldi
#
#                                      original_title  year date_published  \
# 9591   Ivan Groznyy. Skaz vtoroy: Boyarskiy zagovor  1958      12/6/1960
# 53482                                  Nashi Kotyky  2020      1/30/2020
# 38069                 Viktor Vogel - Commercial Man  2001      6/14/2002
# 17397                        Le corps de mon ennemi  1976           1977
# 71603           Dead in a Week (Or Your Money Back)  2018     11/22/2018
#
#                        genre  duration               country  \
# 9591      Biography, History        88          Soviet Union
# 53482                 Comedy       110  Ukraine, USA, Canada
# 38069        Comedy, Romance       108               Germany
# 17397  Crime, Drama, Mystery       116                France
# 71603          Comedy, Drama        90                    UK
#
#                  language              director  ...  \
# 9591              Russian  Sergei M. Eisenstein  ...
# 53482  Ukrainian, Russian      Volodymyr Tykhyy  ...
# 38069              German           Lars Kraume  ...
# 17397              French        Henri Verneuil  ...
# 71603             English           Tom Edmunds  ...
#
#                                                   actors  \
# 9591   Nikolay Cherkasov, Serafima Birman, Pavel Kado...
# 53482  Dmytro Tuboltsev, Stanislav Bzhezinskyi, Petro...
# 38069  Alexander Scheer, Götz George, Chulpan Khamato...
# 17397  Jean-Paul Belmondo, Bernard Blier, Marie-Franc...
# 71603  Tom Wilkinson, Aneurin Barnard, Marion Bailey,...
#
#                                              description avg_vote votes  \
# 9591   As Ivan the Terrible attempts to consolidate h...      7.9  6567
# 53482  In 2014 Russia's hybrid war against Ukraine tu...      8.4   682
# 38069  Viktor Vogel gets a huge career boost when he ...      5.8   706
# 17397  Francois always despised the textile barons wh...      6.7  1483
# 71603  After his ninth unsuccessful attempt on his ow...      6.2  4742
#
#              budget  usa_gross_income worlwide_gross_income metascore  \
# 9591            NaN               NaN               $1,655        NaN
# 53482           NaN               NaN             $350,515        NaN
# 38069  $12,000,000                NaN              $32,933        NaN
# 17397  FRF 15000000               NaN                   NaN       NaN
# 71603           NaN               NaN             $839,568       38.0
#
#       reviews_from_users  reviews_from_critics
# 9591                40.0                  32.0
# 53482               19.0                   NaN
# 38069               16.0                  13.0
# 17397                4.0                  10.0
# 71603               70.0                  36.0
#
# [5 rows x 22 columns]

# %%
##Read Columns

for col in IMBD_df.columns: 
    print(col)
# Out:
# imdb_title_id
# title
# original_title
# year
# date_published
# genre
# duration
# country
# language
# director
# writer
# production_company
# actors
# description
# avg_vote
# votes
# budget
# usa_gross_income
# worlwide_gross_income
# metascore
# reviews_from_users
# reviews_from_critics

# %%
##Cast year in to integer so to sort and drop
IMBD_df[['year']] = IMBD_df[['year']].apply(pd.to_numeric) 
print(IMBD_df.dtypes)
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                       int64
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %%
##Cast year in to integer so to sort and drop

IMBD_df = IMBD_df[(IMBD_df.country == "USA") & (IMBD_df.year > 1999) & (IMBD_df.year < 2018)] 
IMBD_df.sample(5)
# Out:
#       imdb_title_id                 title                original_title  year  \
# 62008     tt1791611    Spreading Darkness            Spreading Darkness  2017
# 59321     tt1550524  White Irish Drinkers          White Irish Drinkers  2010
# 55349     tt1201135         Barking Water                 Barking Water  2009
# 53495     tt1074214     6 mogli e un papà  The Six Wives of Henry Lefay  2009
# 55720     tt1230211           Perkins' 14                   Perkins' 14  2009
#
#       date_published                 genre  duration country language  \
# 62008     11/14/2017  Action, Crime, Drama       101     USA  English
# 59321      3/25/2011                 Drama       109     USA  English
# 55349       9/1/2009                 Drama        85     USA  English
# 53495      6/18/2009                Comedy        95     USA  English
# 55720      3/24/2010      Horror, Thriller        95     USA  English
#
#                    director  ...  \
# 62008       Josh Eisenstadt  ...
# 59321             John Gray  ...
# 55349         Sterlin Harjo  ...
# 53495  Howard Michael Gould  ...
# 55720          Craig Singer  ...
#
#                                                   actors  \
# 62008  Eric Roberts, John Savage, James Duval, Domini...
# 59321  Nick Thurston, Geoffrey Wigdor, Karen Allen, S...
# 55349  Bebe Harjo, Gabriel Pelayo, Frederick Schroede...
# 53495  Tim Allen, Barbara Barrie, Elisha Cuthbert, Je...
# 55720  Patrick O'Kane, Richard Brake, Michale Graves,...
#
#                                              description avg_vote votes  \
# 62008  A corrupt CEO grows increasingly paranoid he i...      3.5   124
# 59321  Brooklyn, 1975: two brothers looking for a way...      6.8  1743
# 55349  Frankie is dying. Irene hasn't forgiven him. A...      5.9   159
# 53495  A grieving daughter tries to arrange her fathe...      5.1  2986
# 55720  In the small town of Stone Cove, Maine, deputy...      5.0  2124
#
#           budget  usa_gross_income worlwide_gross_income metascore  \
# 62008        NaN               NaN                   NaN       NaN
# 59321        NaN          $31,056               $31,056       51.0
# 55349  $200,000                NaN                   NaN       NaN
# 53495        NaN               NaN                   NaN       NaN
# 55720        NaN               NaN             $103,054        NaN
#
#       reviews_from_users  reviews_from_critics
# 62008                NaN                   NaN
# 59321               34.0                  26.0
# 55349                NaN                   6.0
# 53495               11.0                   9.0
# 55720               25.0                  23.0
#
# [5 rows x 22 columns]

# %%
## Choose Columns,  drop rows where reviews_from_critics is NaN, remove duplicate movies
IMBD_df = IMBD_df.rename(columns={'title': 'movie_title'})
IMBD_df = IMBD_df[['movie_title', 'year', 'genre', 'duration', 'director', 'description', 'avg_vote', 'reviews_from_users', 'reviews_from_critics']].copy()

IMBD_df=IMBD_df.drop_duplicates(['movie_title'] , keep ='first') 

IMBD_df = IMBD_df.reset_index(drop=True)
IMBD_df.to_csv("../Output/IMBD_clean.csv")

IMBD_df.sample(10)
# Out:
#                       movie_title  year                       genre  duration  \
# 8540                     Homeless  2015                       Drama        92
# 6412                    The Ideal  2011   Fantasy, Horror, Thriller        96
# 486                     Novocaine  2001        Comedy, Crime, Drama        95
# 8118                         Lily  2013                       Drama        85
# 4814                  In the Gray  2012                Crime, Drama       122
# 2766           Omen - Il presagio  2006  Action, Adventure, Fantasy       110
# 8344                Feels So Good  2013                      Comedy        81
# 6987                 Abel's Field  2012                       Drama       104
# 10555  The Mustanger and the Lady  2017            Romance, Western       108
# 3037             My Name Is Bruce  2007     Comedy, Fantasy, Horror        84
#
#                  director                                        description  \
# 8540   Clay Riley Hassler  An 18 year old boy navigates his way through l...
# 6412    Wes Tomasz Ciesla  It's a high school summer job for Julia and Al...
# 486          David Atkins  A dentist finds himself a murder suspect after...
# 8118           Matt Creed  Lily is an exploration of a vulnerable period ...
# 4814         Rob Holloway  Undercover narcotics officer Yancy is always f...
# 2766           John Moore  An American official realizes that his young s...
# 8344        Josh Stolberg  After his best friend loses his virginity, soc...
# 6987      Gordie Haakstad  An inspiring drama about a solitary high schoo...
# 10555        James Cotten  Julie's time with her benefactor, Kyle Allison...
# 3037       Bruce Campbell  Mistaken for his character Ash from the 'Evil ...
#
#        avg_vote  reviews_from_users  reviews_from_critics
# 8540        6.5                 8.0                   7.0
# 6412        2.3                11.0                   3.0
# 486         5.8               102.0                  73.0
# 8118        5.9                 2.0                   7.0
# 4814        7.0                 NaN                   NaN
# 2766        5.5               568.0                 239.0
# 8344        5.4                 2.0                   NaN
# 6987        6.5                10.0                   1.0
# 10555       6.2                29.0                  10.0
# 3037        6.2                93.0                 108.0

# %%
#Connect to Local Database

rds_connection_string = "postgres:postgres@localhost:5432/ETL_project_movie_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#Check for tables
engine.table_names()
# Out:
# ['imbd_data']

# %%
### Use pandas to load csv converted DataFrame into database
IMBD_df.to_sql(name='imbd_data', con=engine, if_exists='append', index=False)

# %%
##Confirm data has been added by querying the netflix_data table
pd.read_sql_query('select * from imbd_data', con=engine).head()
# Out:
#          movie_title  year                     genre  duration  \
# 0     Kate & Leopold  2001  Comedy, Fantasy, Romance       118
# 1  The Naked Monster  2005    Comedy, Horror, Sci-Fi       100
# 2    The Fantasticks  2000          Musical, Romance        86
# 3      For the Cause  2000  Action, Adventure, Drama       100
# 4   The Silent Force  2001                    Action        90
#
#                      director  \
# 0               James Mangold
# 1   Wayne Berwick, Ted Newsom
# 2             Michael Ritchie
# 3  David Douglas, Tim Douglas
# 4                David H. May
#
#                                          description  avg_vote  \
# 0  An English Duke from 1876 is inadvertedly drag...       6.4
# 1  A brain-dead sheriff, a stolid secret agent an...       5.4
# 2  A mysterious fair that comes to a small commun...       5.6
# 3  Earth is in a state of constant war and two co...       3.5
# 4  An elite Federal force whose objective is to e...       4.3
#
#    reviews_from_users  reviews_from_critics
# 0               341.0                 115.0
# 1                15.0                   8.0
# 2                70.0                  24.0
# 3                 9.0                   7.0
# 4                 5.0                   4.0

# %%
#See how many movies by release year

IMBD__by_year_df = IMBD_df["year"].value_counts()
IMBD__by_year_df.head()
# Out:
# 2017    885
# 2016    839
# 2013    799
# 2014    787
# 2015    782
# Name: year, dtype: int64
